# %%
import datetime
from unicodedata import decimal
import wbgapi as wb
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from plotly.subplots import make_subplots

# %%
wb.region.info()
# Out:
# code    name
# ------  -----------------------------------------------------
# AFE     Africa Eastern and Southern
# AFR     Africa
# AFW     Africa Western and Central
# ARB     Arab World
# CAA     Sub-Saharan Africa (IFC classification)
# CEA     East Asia and the Pacific (IFC classification)
# CEB     Central Europe and the Baltics
# CEU     Europe and Central Asia (IFC classification)
# CLA     Latin America and the Caribbean (IFC classification)
# CME     Middle East and North Africa (IFC classification)
# CSA     South Asia (IFC classification)
# CSS     Caribbean small states
# EAP     East Asia & Pacific (excluding high income)
# EAR     Early-demographic dividend
# EAS     East Asia & Pacific
# ECA     Europe & Central Asia (excluding high income)
# ECS     Europe & Central Asia
# EMU     Euro area
# EUU     European Union
# FCS     Fragile and conflict affected situations
# HPC     Heavily indebted poor countries (HIPC)
# LAC     Latin America & Caribbean (excluding high income)
# LCN     Latin America & Caribbean
# LDC     Least developed countries: UN classification
# LTE     Late-demographic dividend
# MDE     Middle East (developing only)
# MEA     Middle East & North Africa
# MNA     Middle East & North Africa (excluding high income)
# NAC     North America
# NAF     North Africa
# NRS     Non-resource rich Sub-Saharan Africa countries
# OED     OECD members
# OSS     Other small states
# PRE     Pre-demographic dividend
# PSS     Pacific island small states
# PST     Post-demographic dividend
# RRS     Resource rich Sub-Saharan Africa countries
# SAS     South Asia
# SSA     Sub-Saharan Africa (excluding high income)
# SSF     Sub-Saharan Africa
# SST     Small states
# SXZ     Sub-Saharan Africa excluding South Africa
# WLD     World
# XZN     Sub-Saharan Africa excluding South Africa and Nigeria
#         44 elements

# %% [markdown]
# ## Adolescent fertility rate (births per 1,000 women ages 15-19)

# %%
#World(WLD)
AfrWLD=wb.data.DataFrame('SP.ADO.TFRT', wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
AfrCLA=wb.data.DataFrame('SP.ADO.TFRT', wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
AfrAFR=wb.data.DataFrame('SP.ADO.TFRT', wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
AfrEUU=wb.data.DataFrame('SP.ADO.TFRT', wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
AfrSAS=wb.data.DataFrame('SP.ADO.TFRT', wb.region.members('SAS'), range(2010, 2023, 1))
AfrWLD.head()
# Out:
#            YR2010    YR2011   YR2012    YR2013    YR2014    YR2015    YR2016  \
# economy
# ABW       30.6520   29.5820   28.512   27.3444   26.1768   25.0092   23.8416
# AFG      113.7150  107.2560  100.797   94.4290   88.0610   81.6930   75.3250
# AGO      172.9316  170.1658  167.400  164.0252  160.6504  157.2756  153.9008
# ALB       19.8208   20.2754   20.730   20.5124   20.2948   20.0772   19.8596
# AND           NaN       NaN      NaN       NaN       NaN       NaN       NaN
#
#           YR2017    YR2018    YR2019    YR2020  YR2021
# economy
# ABW       22.674   21.1736   19.6732   18.1728     NaN
# AFG       68.957   65.1410   61.3250   57.5090     NaN
# AGO      150.526  147.9580  145.3900  142.8220     NaN
# ALB       19.642   19.5724   19.5028   19.4332     NaN
# AND          NaN       NaN       NaN       NaN     NaN

# %% [markdown]
# ## Birth rate, crude (per 1000 people)

# %%
#World(WLD)
BrcWLD=wb.data.DataFrame('SP.DYN.CBRT.IN', wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
BrcCLA=wb.data.DataFrame('SP.DYN.CBRT.IN', wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
BrcAFR=wb.data.DataFrame('SP.DYN.CBRT.IN', wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
BrcEUU=wb.data.DataFrame('SP.DYN.CBRT.IN', wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
BrcSAS=wb.data.DataFrame('SP.DYN.CBRT.IN', wb.region.members('SAS'), range(2010, 2023, 1))
BrcWLD.head()
# Out:
#          YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy
# ABW      11.214  11.123  11.090  11.111  11.179  11.281  11.404  11.532
# AFG      39.829  38.750  37.690  36.670  35.706  34.809  33.981  33.211
# AGO      45.656  45.102  44.493  43.847  43.182  42.520  41.882  41.281
# ALB      12.001  12.100  12.197  12.257  12.259  12.197  12.080  11.934
# AND       9.800     NaN   9.500     NaN     NaN     NaN   8.800     NaN
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# ABW      11.652  11.756  11.841     NaN
# AFG      32.487  31.802  31.153     NaN
# AGO      40.729  40.232  39.791     NaN
# ALB      11.780  11.620  11.453     NaN
# AND       7.200   7.000     NaN     NaN

# %% [markdown]
# ## Births attended by skilled health staff (% of total)

# %%
#World(WLD)
BashWLD=wb.data.DataFrame('SH.STA.BRTC.ZS', wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
BashCLA=wb.data.DataFrame('SH.STA.BRTC.ZS', wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
BashAFR=wb.data.DataFrame('SH.STA.BRTC.ZS', wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
BashEUU=wb.data.DataFrame('SH.STA.BRTC.ZS', wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
BashSAS=wb.data.DataFrame('SH.STA.BRTC.ZS', wb.region.members('SAS'), range(2010, 2023, 1))
BashWLD.head()
# Out:
#          YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy
# ABW         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AFG        34.3    38.6    39.9     NaN    45.2    50.5     NaN    53.4
# AGO         NaN     NaN     NaN     NaN     NaN     NaN    49.6     NaN
# ALB         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AND         NaN     NaN     NaN     NaN     NaN   100.0   100.0   100.0
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# ABW         NaN     NaN     NaN     NaN
# AFG        58.8     NaN    61.8     NaN
# AGO         NaN     NaN     NaN     NaN
# ALB        99.8     NaN     NaN     NaN
# AND         NaN     NaN     NaN     NaN

# %% [markdown]
# ## Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)

# %%
#World(WLD)
CodpnWLD=wb.data.DataFrame('SH.DTH.COMM.ZS', wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
CodpnCLA=wb.data.DataFrame('SH.DTH.COMM.ZS', wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
CodpnAFR=wb.data.DataFrame('SH.DTH.COMM.ZS', wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
CodpnEUU=wb.data.DataFrame('SH.DTH.COMM.ZS', wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
CodpnSAS=wb.data.DataFrame('SH.DTH.COMM.ZS', wb.region.members('SAS'), range(2010, 2023, 1))
CodpnWLD.head()
# Out:
#             YR2010  YR2011  YR2012  YR2013  YR2014     YR2015  YR2016  YR2017  \
# economy
# ABW            NaN     NaN     NaN     NaN     NaN        NaN     NaN     NaN
# AFG      48.149914     NaN     NaN     NaN     NaN  39.390981     NaN     NaN
# AGO      66.606996     NaN     NaN     NaN     NaN  61.575382     NaN     NaN
# ALB       3.259132     NaN     NaN     NaN     NaN   2.955382     NaN     NaN
# AND            NaN     NaN     NaN     NaN     NaN        NaN     NaN     NaN
#
#          YR2018     YR2019  YR2020  YR2021
# economy
# ABW         NaN        NaN     NaN     NaN
# AFG         NaN  32.930451     NaN     NaN
# AGO         NaN  59.162273     NaN     NaN
# ALB         NaN   3.023108     NaN     NaN
# AND         NaN        NaN     NaN     NaN

# %% [markdown]
# ## Capital health expenditure (% of GDP)

# %%
#World(WLD)
CheWLD=wb.data.DataFrame('SH.STA.BRTC.ZS', wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
CheCLA=wb.data.DataFrame('SH.STA.BRTC.ZS', wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
CheAFR=wb.data.DataFrame('SH.STA.BRTC.ZS', wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
CheEUU=wb.data.DataFrame('SH.STA.BRTC.ZS', wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
CheSAS=wb.data.DataFrame('SH.STA.BRTC.ZS', wb.region.members('SAS'), range(2010, 2023, 1))
CheWLD.head()
# Out:
#          YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy
# ABW         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AFG        34.3    38.6    39.9     NaN    45.2    50.5     NaN    53.4
# AGO         NaN     NaN     NaN     NaN     NaN     NaN    49.6     NaN
# ALB         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AND         NaN     NaN     NaN     NaN     NaN   100.0   100.0   100.0
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# ABW         NaN     NaN     NaN     NaN
# AFG        58.8     NaN    61.8     NaN
# AGO         NaN     NaN     NaN     NaN
# ALB        99.8     NaN     NaN     NaN
# AND         NaN     NaN     NaN     NaN

# %% [markdown]
# ## Current health expenditure (% of GDP)

# %%
#World(WLD)
CuheWLD=wb.data.DataFrame('SH.XPD.CHEX.GD.ZS', wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
CuheCLA=wb.data.DataFrame('SH.XPD.CHEX.GD.ZS', wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
CuheAFR=wb.data.DataFrame('SH.XPD.CHEX.GD.ZS', wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
CuheEUU=wb.data.DataFrame('SH.XPD.CHEX.GD.ZS', wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
CuheSAS=wb.data.DataFrame('SH.XPD.CHEX.GD.ZS', wb.region.members('SAS'), range(2010, 2023, 1))
CuheWLD.head()
# Out:
#            YR2010    YR2011    YR2012    YR2013    YR2014     YR2015  \
# economy
# ABW           NaN       NaN       NaN       NaN       NaN        NaN
# AFG      8.569672  8.561907  7.897176  8.805941  9.528871  10.105348
# AGO      2.695100  2.645608  2.395750  2.732828  2.434129   2.605795
# ALB      4.745796  4.795341  5.055265  5.385611  5.503473   4.896312
# AND      6.580060  6.086336  6.126280  6.155028  6.131505   6.283535
#
#             YR2016     YR2017     YR2018     YR2019  YR2020  YR2021
# economy
# ABW            NaN        NaN        NaN        NaN     NaN     NaN
# AFG      11.818562  12.620817  14.126743  13.242202     NaN     NaN
# AGO       2.713149   2.791503   2.540102   2.533360     NaN     NaN
# ALB       4.916017   5.012636   5.232072        NaN     NaN     NaN
# AND       6.305263   6.589455   6.751625   6.711585     NaN     NaN

# %% [markdown]
# ## Current health expenditure per capita (current US$)

# %%
#World(WLD)
CuhepcWLD=wb.data.DataFrame("SH.XPD.CHEX.PC.CD", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
CuhepcCLA=wb.data.DataFrame("SH.XPD.CHEX.PC.CD", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
CuhepcAFR=wb.data.DataFrame("SH.XPD.CHEX.PC.CD", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
CuhepcEUU=wb.data.DataFrame("SH.XPD.CHEX.PC.CD", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
CuhepcSAS=wb.data.DataFrame("SH.XPD.CHEX.PC.CD", wb.region.members('SAS'), range(2010, 2023, 1))
CuhepcWLD.head()
# Out:
#               YR2010       YR2011       YR2012       YR2013       YR2014  \
# economy
# ABW              NaN          NaN          NaN          NaN          NaN
# AFG        44.990532    50.853474    51.440262    55.034630    59.008934
# AGO        96.697014   122.107231   122.185585   143.606873   131.647659
# ALB       192.003220   211.075516   213.719742   236.957962   251.358261
# AND      2685.479736  2634.032715  2370.057129  2432.782715  2529.089844
#
#               YR2015       YR2016       YR2017       YR2018       YR2019  \
# economy
# ABW              NaN          NaN          NaN          NaN          NaN
# AFG        58.906528    60.188671    65.706024    69.998604    65.806030
# AGO       108.582939    95.124977   114.334602    87.310738    71.326004
# ALB       192.885132   202.013321   226.280670   274.914093          NaN
# AND      2246.254395  2361.217529  2567.423828  2821.801270  2744.194336
#
#          YR2020  YR2021
# economy
# ABW         NaN     NaN
# AFG         NaN     NaN
# AGO         NaN     NaN
# ALB         NaN     NaN
# AND         NaN     NaN

# %% [markdown]
# ## Death rate, crude (per 1,000 people)

# %%
#World(WLD)
DrcmWLD=wb.data.DataFrame("SP.DYN.CDRT.IN", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
DrcmCLA=wb.data.DataFrame("SP.DYN.CDRT.IN", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
DrcmAFR=wb.data.DataFrame("SP.DYN.CDRT.IN", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
DrcmEUU=wb.data.DataFrame("SP.DYN.CDRT.IN", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
DrcmSAS=wb.data.DataFrame("SP.DYN.CDRT.IN", wb.region.members('SAS'), range(2010, 2023, 1))
DrcmWLD.head()
# Out:
#          YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy
# ABW       7.918   8.061   8.205   8.347   8.488   8.627   8.765   8.907
# AFG       8.250   7.936   7.645   7.380   7.141   6.929   6.742   6.575
# AGO      11.680  11.039  10.451   9.921   9.454   9.052   8.716   8.432
# ALB       6.841   6.915   6.996   7.096   7.219   7.367   7.534   7.714
# AND       2.800     NaN   3.900     NaN     NaN     NaN   4.300     NaN
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# ABW       9.053   9.205   9.362     NaN
# AFG       6.423   6.285   6.157     NaN
# AGO       8.190   7.981   7.798     NaN
# ALB       7.898   8.082   8.263     NaN
# AND       4.400   3.900     NaN     NaN

# %% [markdown]
# ## Fertility rate, total (births per woman)

# %%
#World(WLD)
FrtbWLD=wb.data.DataFrame("SP.DYN.TFRT.IN", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
FrtbCLA=wb.data.DataFrame("SP.DYN.TFRT.IN", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
FrtbAFR=wb.data.DataFrame("SP.DYN.TFRT.IN", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
FrtbEUU=wb.data.DataFrame("SP.DYN.TFRT.IN", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
FrtbSAS=wb.data.DataFrame("SP.DYN.TFRT.IN", wb.region.members('SAS'), range(2010, 2023, 1))
FrtbWLD.head()
# Out:
#          YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy
# ABW       1.768   1.779   1.795   1.813   1.834   1.854   1.872   1.886
# AFG       5.977   5.770   5.562   5.359   5.163   4.976   4.800   4.633
# AGO       6.194   6.120   6.039   5.953   5.864   5.774   5.686   5.600
# ALB       1.660   1.673   1.684   1.690   1.688   1.677   1.659   1.638
# AND       1.270     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# ABW       1.896   1.901   1.901     NaN
# AFG       4.473   4.321   4.176     NaN
# AGO       5.519   5.442   5.371     NaN
# ALB       1.617   1.597   1.580     NaN
# AND         NaN     NaN     NaN     NaN

# %% [markdown]
# ## Life expectancy at birth, female (years)

# %%
#World(WLD)
LebfWLD=wb.data.DataFrame("SP.DYN.LE00.FE.IN", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
LebfCLA=wb.data.DataFrame("SP.DYN.LE00.FE.IN", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
LebfAFR=wb.data.DataFrame("SP.DYN.LE00.FE.IN", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
LebfEUU=wb.data.DataFrame("SP.DYN.LE00.FE.IN", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
LebfSAS=wb.data.DataFrame("SP.DYN.LE00.FE.IN", wb.region.members('SAS'), range(2010, 2023, 1))
LebfWLD.head()
# Out:
#          YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy
# ABW      77.425  77.561  77.695  77.830  77.965  78.101  78.237  78.372
# AFG      62.459  63.000  63.514  63.999  64.453  64.877  65.275  65.656
# AGO      58.033  59.052  59.992  60.841  61.591  62.237  62.783  63.252
# ALB      79.302  79.554  79.770  79.934  80.045  80.107  80.134  80.148
# AND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# ABW      78.507  78.641  78.774     NaN
# AFG      66.026  66.388  66.744     NaN
# AGO      63.666  64.039  64.383     NaN
# ALB      80.167  80.201  80.256     NaN
# AND         NaN     NaN     NaN     NaN

# %% [markdown]
# ## Life expectancy at birth, male (years)

# %%
#World(WLD)
LebmWLD=wb.data.DataFrame("SP.DYN.LE00.MA.IN", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
LebmCLA=wb.data.DataFrame("SP.DYN.LE00.MA.IN", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
LebmAFR=wb.data.DataFrame("SP.DYN.LE00.MA.IN", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
LebmEUU=wb.data.DataFrame("SP.DYN.LE00.MA.IN", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
LebmSAS=wb.data.DataFrame("SP.DYN.LE00.MA.IN", wb.region.members('SAS'), range(2010, 2023, 1))
LebmWLD.head()
# Out:
#          YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy
# ABW      72.517  72.654  72.792  72.930  73.069  73.208  73.348  73.488
# AFG      59.683  60.190  60.675  61.133  61.563  61.965  62.343  62.701
# AGO      52.848  53.790  54.660  55.447  56.140  56.737  57.242  57.677
# ALB      74.145  74.552  74.966  75.364  75.734  76.066  76.353  76.601
# AND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# ABW      73.628  73.768  73.908     NaN
# AFG      63.047  63.382  63.708     NaN
# AGO      58.064  58.416  58.744     NaN
# ALB      76.816  77.002  77.163     NaN
# AND         NaN     NaN     NaN     NaN

# %% [markdown]
# ## Life expectancy at birth, total (years)

# %%
#World(WLD)
LebWLD=wb.data.DataFrame("SP.DYN.LE00.IN", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
LebCLA=wb.data.DataFrame("SP.DYN.LE00.IN", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
LebAFR=wb.data.DataFrame("SP.DYN.LE00.IN", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
LebEUU=wb.data.DataFrame("SP.DYN.LE00.IN", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
LebSAS=wb.data.DataFrame("SP.DYN.LE00.IN", wb.region.members('SAS'), range(2010, 2023, 1))
LebWLD.head()
# Out:
#          YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy
# ABW      75.017  75.158  75.299  75.441  75.583  75.725  75.868  76.010
# AFG      61.028  61.553  62.054  62.525  62.966  63.377  63.763  64.130
# AGO      55.350  56.330  57.236  58.054  58.776  59.398  59.925  60.379
# ALB      76.562  76.914  77.252  77.554  77.813  78.025  78.194  78.333
# AND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# ABW      76.152  76.293  76.434     NaN
# AFG      64.486  64.833  65.173     NaN
# AGO      60.782  61.147  61.487     NaN
# ALB      78.458  78.573  78.686     NaN
# AND         NaN     NaN     NaN     NaN

# %% [markdown]
# ## Low-birthweight babies (% of births)

# %%
#World(WLD)
LbbWLD=wb.data.DataFrame("SH.STA.BRTW.ZS", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
LbbCLA=wb.data.DataFrame("SH.STA.BRTW.ZS", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
LbbAFR=wb.data.DataFrame("SH.STA.BRTW.ZS", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
LbbEUU=wb.data.DataFrame("SH.STA.BRTW.ZS", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
LbbSAS=wb.data.DataFrame("SH.STA.BRTW.ZS", wb.region.members('SAS'), range(2010, 2023, 1))
LbbWLD.head()
# Out:
#             YR2010     YR2011    YR2012     YR2013     YR2014     YR2015  \
# economy
# ABW            NaN        NaN       NaN        NaN        NaN        NaN
# AFG            NaN        NaN       NaN        NaN        NaN        NaN
# AGO      16.094879  15.939230  15.76963  15.596671  15.430819  15.256593
# ALB       4.657297   4.641124   4.62757   4.614613   4.599878   4.587830
# AND       7.444220   7.447797   7.45284   7.453817   7.450900   7.445405
#
#          YR2016  YR2017  YR2018  YR2019  YR2020  YR2021
# economy
# ABW         NaN     NaN     NaN     NaN     NaN     NaN
# AFG         NaN     NaN     NaN     NaN     NaN     NaN
# AGO         NaN     NaN     NaN     NaN     NaN     NaN
# ALB         NaN     NaN     NaN     NaN     NaN     NaN
# AND         NaN     NaN     NaN     NaN     NaN     NaN

# %% [markdown]
# ## Mortality rate, adult, female (per 1,000 female adults)

# %%
#World(WLD)
MrafWLD=wb.data.DataFrame("SP.DYN.AMRT.FE", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
MrafCLA=wb.data.DataFrame("SP.DYN.AMRT.FE", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
MrafAFR=wb.data.DataFrame("SP.DYN.AMRT.FE", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
MrafEUU=wb.data.DataFrame("SP.DYN.AMRT.FE", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
MrafSAS=wb.data.DataFrame("SP.DYN.AMRT.FE", wb.region.members('SAS'), range(2010, 2023, 1))
MrafWLD.head()
# Out:
#           YR2010   YR2011   YR2012   YR2013   YR2014   YR2015   YR2016  \
# economy
# ABW       76.722   75.655   74.589   73.561   72.534   71.506   70.479
# AFG      228.971  224.280  219.588  215.307  211.026  206.746  202.465
# AGO      233.617  224.597  215.577  212.458  209.339  206.219  203.100
# ALB       55.689   54.425   53.161   52.505   51.850   51.195   50.539
# AND          NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#           YR2017   YR2018   YR2019   YR2020  YR2021
# economy
# ABW       69.451   68.514   67.577   66.641     NaN
# AFG      198.184  192.532  188.839  185.146     NaN
# AGO      199.981  220.291  216.821  213.350     NaN
# ALB       49.884   49.486   49.088   48.690     NaN
# AND          NaN      NaN      NaN      NaN     NaN

# %% [markdown]
# ## Mortality rate, adult, male (per 1,000 male adults)

# %%
#World(WLD)
MramWLD=wb.data.DataFrame("SP.DYN.AMRT.MA", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
MramCLA=wb.data.DataFrame("SP.DYN.AMRT.MA", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
MramAFR=wb.data.DataFrame("SP.DYN.AMRT.MA", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
MramEUU=wb.data.DataFrame("SP.DYN.AMRT.MA", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
MramSAS=wb.data.DataFrame("SP.DYN.AMRT.MA", wb.region.members('SAS'), range(2010, 2023, 1))
MramWLD.head()
# Out:
#           YR2010   YR2011   YR2012   YR2013   YR2014   YR2015   YR2016  \
# economy
# ABW      123.598  121.954  120.311  118.655  116.999  115.343  113.686
# AFG      271.299  266.320  261.340  257.135  252.930  248.724  244.519
# AGO      306.825  297.976  289.127  285.989  282.850  279.712  276.573
# ALB      106.184  106.273  106.363  103.981  101.598   99.215   96.833
# AND          NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#           YR2017   YR2018   YR2019   YR2020  YR2021
# economy
# ABW      112.030  110.630  109.044  107.459     NaN
# AFG      240.314  237.554  233.884  230.214     NaN
# AGO      273.435  327.044  323.091  319.137     NaN
# ALB       94.450   93.315   92.179   91.044     NaN
# AND          NaN      NaN      NaN      NaN     NaN

# %% [markdown]
# ## Mortality rate, infant (per 1,000 live births)

# %%
#World(WLD)
MriWLD=wb.data.DataFrame("SP.DYN.IMRT.IN", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
MriCLA=wb.data.DataFrame("SP.DYN.IMRT.IN", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
MriAFR=wb.data.DataFrame("SP.DYN.IMRT.IN", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
MriEUU=wb.data.DataFrame("SP.DYN.IMRT.IN", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
MriSAS=wb.data.DataFrame("SP.DYN.IMRT.IN", wb.region.members('SAS'), range(2010, 2023, 1))
MriWLD.head()
# Out:
#          YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy
# ABW         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AFG        64.2    61.8    59.5    57.3    55.2    53.2    51.3    49.5
# AGO        75.9    71.5    67.4    63.7    60.5    57.7    55.5    53.5
# ALB        11.8    10.8    10.0     9.3     8.8     8.5     8.4     8.4
# AND         4.1     3.9     3.7     3.5     3.3     3.1     2.9     2.8
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# ABW         NaN     NaN     NaN     NaN
# AFG        47.9    46.4    45.0     NaN
# AGO        51.7    49.9    48.3     NaN
# ALB         8.5     8.6     8.8     NaN
# AND         2.6     2.5     2.4     NaN

# %% [markdown]
# ## Population growth (annual %)

# %%
#World(WLD)
PgaWLD=wb.data.DataFrame("SP.POP.GROW", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
PgaCLA=wb.data.DataFrame("SP.POP.GROW", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
PgaAFR=wb.data.DataFrame("SP.POP.GROW", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
PgaEUU=wb.data.DataFrame("SP.POP.GROW", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
PgaSAS=wb.data.DataFrame("SP.POP.GROW", wb.region.members('SAS'), range(2010, 2023, 1))
PgaWLD.head()
# Out:
#            YR2010    YR2011    YR2012    YR2013    YR2014    YR2015    YR2016  \
# economy
# ABW      0.209731  0.377979  0.503385  0.583290  0.590508  0.541048  0.502860
# AFG      2.746615  3.143106  3.407600  3.494592  3.355602  3.077054  2.778035
# AGO      3.671493  3.634150  3.597755  3.551997  3.497447  3.438869  3.378269
# ALB     -0.496462 -0.269017 -0.165151 -0.183211 -0.207047 -0.291206 -0.159880
# AND     -0.008288 -0.839472 -1.589924 -2.030744 -1.946518 -1.552135 -0.898981
#
#            YR2017    YR2018    YR2019    YR2020    YR2021
# economy
# ABW      0.471874  0.459266  0.437415  0.428017  0.401008
# AFG      2.547833  2.384309  2.313073  2.303812  2.303412
# AGO      3.322158  3.276145  3.242914  3.218530  3.195916
# ALB     -0.091972 -0.246732 -0.426007 -0.574207 -0.926918
# AND     -0.386281  0.014285  0.179042  0.154134  0.115122

# %% [markdown]
# ## Population, female

# %%
#World(WLD)
PfWLD=wb.data.DataFrame("SP.POP.TOTL.FE.IN", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
PfCLA=wb.data.DataFrame("SP.POP.TOTL.FE.IN", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
PfAFR=wb.data.DataFrame("SP.POP.TOTL.FE.IN", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
PfEUU=wb.data.DataFrame("SP.POP.TOTL.FE.IN", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
PfSAS=wb.data.DataFrame("SP.POP.TOTL.FE.IN", wb.region.members('SAS'), range(2010, 2023, 1))
PfWLD.head()
# Out:
#              YR2010      YR2011      YR2012      YR2013      YR2014  \
# economy
# ABW         53200.0     53402.0     53695.0     54050.0     54408.0
# AFG      14249755.0  14702050.0  15196504.0  15715314.0  16232001.0
# AGO      11806970.0  12245836.0  12694373.0  13151985.0  13618285.0
# ALB       1445588.0   1438949.0   1433116.0   1426832.0   1420670.0
# AND             NaN         NaN         NaN         NaN         NaN
#
#              YR2015      YR2016      YR2017      YR2018      YR2019  \
# economy
# ABW         54742.0     55044.0     55328.0     55602.0     55867.0
# AFG      16727437.0  17196034.0  17644126.0  18078879.0  18512030.0
# AGO      14093136.0  14576127.0  15067450.0  15568328.0  16080520.0
# ALB       1414246.0   1410814.0   1409327.0   1406333.0   1401011.0
# AND             NaN         NaN         NaN         NaN         NaN
#
#              YR2020      YR2021
# economy
# ABW         56124.0     56367.0
# AFG      18952076.0  19400447.0
# AGO      16605398.0  17143471.0
# ALB       1393469.0   1380834.0
# AND             NaN         NaN

# %% [markdown]
# # Population, male

# %%
#World(WLD)
PmWLD=wb.data.DataFrame("SP.POP.TOTL.MA.IN", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
PmCLA=wb.data.DataFrame("SP.POP.TOTL.MA.IN", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
PmAFR=wb.data.DataFrame("SP.POP.TOTL.MA.IN", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
PmEUU=wb.data.DataFrame("SP.POP.TOTL.MA.IN", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
PmSAS=wb.data.DataFrame("SP.POP.TOTL.MA.IN", wb.region.members('SAS'), range(2010, 2023, 1))
PmWLD.head()
# Out:
#              YR2010      YR2011      YR2012      YR2013      YR2014  \
# economy
# ABW         48465.0     48648.0     48870.0     49115.0     49368.0
# AFG      14935756.0  15415361.0  15964874.0  16554278.0  17138803.0
# AGO      11549277.0  11974824.0  12413552.0  12863801.0  13323488.0
# ALB       1467433.0   1466246.0   1467285.0   1468260.0   1468434.0
# AND             NaN         NaN         NaN         NaN         NaN
#
#              YR2015      YR2016      YR2017      YR2018      YR2019  \
# economy
# ABW         49597.0     49821.0     50033.0     50244.0     50443.0
# AFG      17686166.0  18186994.0  18651985.0  19093043.0  19529727.0
# AGO      13791244.0  14266355.0  14749319.0  15241459.0  15744779.0
# ALB       1466457.0   1465287.0   1464130.0   1460043.0   1453180.0
# AND             NaN         NaN         NaN         NaN         NaN
#
#              YR2020      YR2021
# economy
# ABW         50642.0     50828.0
# AFG      19976265.0  20434981.0
# AGO      16260870.0  16790140.0
# ALB       1444380.0   1430832.0
# AND             NaN         NaN

# %% [markdown]
# ## Population, total

# %%
#World(WLD)
PtWLD=wb.data.DataFrame("SP.POP.TOTL", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
PtCLA=wb.data.DataFrame("SP.POP.TOTL", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
PtAFR=wb.data.DataFrame("SP.POP.TOTL", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
PtEUU=wb.data.DataFrame("SP.POP.TOTL", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
PtSAS=wb.data.DataFrame("SP.POP.TOTL", wb.region.members('SAS'), range(2010, 2023, 1))
PtWLD.head()
# Out:
#              YR2010      YR2011      YR2012      YR2013      YR2014  \
# economy
# ABW        101665.0    102050.0    102565.0    103165.0    103776.0
# AFG      29185511.0  30117411.0  31161378.0  32269592.0  33370804.0
# AGO      23356247.0  24220660.0  25107925.0  26015786.0  26941773.0
# ALB       2913021.0   2905195.0   2900401.0   2895092.0   2889104.0
# AND         84454.0     83748.0     82427.0     80770.0     79213.0
#
#              YR2015      YR2016      YR2017      YR2018      YR2019  \
# economy
# ABW        104339.0    104865.0    105361.0    105846.0    106310.0
# AFG      34413603.0  35383028.0  36296111.0  37171922.0  38041757.0
# AGO      27884380.0  28842482.0  29816769.0  30809787.0  31825299.0
# ALB       2880703.0   2876101.0   2873457.0   2866376.0   2854191.0
# AND         77993.0     77295.0     76997.0     77008.0     77146.0
#
#              YR2020      YR2021
# economy
# ABW        106766.0    107195.0
# AFG      38928341.0  39835428.0
# AGO      32866268.0  33933611.0
# ALB       2837849.0   2811666.0
# AND         77265.0     77354.0

# %% [markdown]
# ## Suicide mortality rate (per 100,000 population)

# %%
#World(WLD)
SmrWLD=wb.data.DataFrame("SH.STA.SUIC.P5", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
SmrCLA=wb.data.DataFrame("SH.STA.SUIC.P5", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
SmrAFR=wb.data.DataFrame("SH.STA.SUIC.P5", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
SmrEUU=wb.data.DataFrame("SH.STA.SUIC.P5", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
SmrSAS=wb.data.DataFrame("SH.STA.SUIC.P5", wb.region.members('SAS'), range(2010, 2023, 1))
SmrWLD.head()
# Out:
#          YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy
# ABW         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AFG         4.3     4.1     4.0     4.0     3.9     4.0     4.0     4.1
# AGO         7.0     6.6     6.9     6.9     6.4     6.5     6.2     6.0
# ALB         7.8     7.9     5.2     5.3     5.0     4.8     4.7     4.7
# AND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# ABW         NaN     NaN     NaN     NaN
# AFG         4.1     4.1     NaN     NaN
# AGO         6.0     6.1     NaN     NaN
# ALB         4.5     4.3     NaN     NaN
# AND         NaN     NaN     NaN     NaN

# %% [markdown]
# ## Stillbirth rate (per 1,000 total births)

# %%
wb.data.DataFrame("SH.DYN.STLB", wb.region.members('CLA'), range(2010, 2023, 1)).head()

# %% [markdown]
# ## Suicide mortality rate, female (per 100,000 female population)

# %%
#World(WLD)
SmrfWLD=wb.data.DataFrame("SH.STA.SUIC.FE.P5", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
SmrfCLA=wb.data.DataFrame("SH.STA.SUIC.FE.P5", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
SmrfAFR=wb.data.DataFrame("SH.STA.SUIC.FE.P5", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
SmrfEUU=wb.data.DataFrame("SH.STA.SUIC.FE.P5", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
SmrfSAS=wb.data.DataFrame("SH.STA.SUIC.FE.P5", wb.region.members('SAS'), range(2010, 2023, 1))
SmrfWLD.head()
# Out:
#          YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy
# ABW         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AFG         3.9     3.8     3.7     3.7     3.6     3.6     3.6     3.4
# AGO         2.9     2.7     2.7     2.6     2.4     2.6     2.6     2.4
# ALB         6.1     8.3     3.4     3.5     3.2     3.2     3.1     2.9
# AND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# ABW         NaN     NaN     NaN     NaN
# AFG         3.5     3.6     NaN     NaN
# AGO         2.3     2.3     NaN     NaN
# ALB         2.8     2.7     NaN     NaN
# AND         NaN     NaN     NaN     NaN

# %% [markdown]
# ## Suicide mortality rate, male (per 100,000 male population)

# %%
#World(WLD)
SmrmWLD=wb.data.DataFrame("SH.STA.SUIC.MA.P5", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
SmrmCLA=wb.data.DataFrame("SH.STA.SUIC.MA.P5", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
SmrmAFR=wb.data.DataFrame("SH.STA.SUIC.MA.P5", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
SmrmEUU=wb.data.DataFrame("SH.STA.SUIC.MA.P5", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
SmrmSAS=wb.data.DataFrame("SH.STA.SUIC.MA.P5", wb.region.members('SAS'), range(2010, 2023, 1))
SmrmWLD.head()
# Out:
#          YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy
# ABW         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AFG         4.6     4.5     4.3     4.3     4.2     4.3     4.4     4.6
# AGO        11.2    10.6    11.2    11.3    10.4    10.5    10.0     9.7
# ALB         9.5     7.5     6.9     6.9     6.6     6.3     6.3     6.3
# AND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# ABW         NaN     NaN     NaN     NaN
# AFG         4.6     4.6     NaN     NaN
# AGO         9.8    10.0     NaN     NaN
# ALB         6.2     5.9     NaN     NaN
# AND         NaN     NaN     NaN     NaN

# %% [markdown]
# ## Wanted fertility rate (births per woman)

# %%
#World(WLD)
WfrWLD=wb.data.DataFrame("SP.DYN.WFRT", wb.region.members('WLD'), range(2010, 2023, 1))
#Latin America and the Caribbean(IFC classification)(CLA)
WfrCLA=wb.data.DataFrame("SP.DYN.WFRT", wb.region.members('CLA'), range(2010, 2023, 1))
#Africa(AFR)
WfrAFR=wb.data.DataFrame("SP.DYN.WFRT", wb.region.members('AFR'), range(2010, 2023, 1))
#European Union(EUU)
WfrEUU=wb.data.DataFrame("SP.DYN.WFRT", wb.region.members('EUU'), range(2010, 2023, 1))
#South Asia(IFC classification)(SAS)
WfrSAS=wb.data.DataFrame("SP.DYN.WFRT", wb.region.members('SAS'), range(2010, 2023, 1))
WfrWLD.head()
# Out:
#          YR2010  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  YR2017  \
# economy
# ABW         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AFG         NaN     NaN     NaN     NaN     NaN     4.4     NaN     NaN
# AGO         NaN     NaN     NaN     NaN     NaN     NaN     5.2     NaN
# ALB         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# AND         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#          YR2018  YR2019  YR2020  YR2021
# economy
# ABW         NaN     NaN     NaN     NaN
# AFG         NaN     NaN     NaN     NaN
# AGO         NaN     NaN     NaN     NaN
# ALB         1.6     NaN     NaN     NaN
# AND         NaN     NaN     NaN     NaN

# %% [markdown]
# ## Age Standardized NCD Mortality Rate (per 100 000 population)(Both sexes)

# %%
ASNMR= pd.read_csv("WHO.csv")
ASNMR.head(2)
# Out:
#   IndicatorCode                                          Indicator ValueType  \
# 0      WHS2_131  Age-standardized NCD mortality rate  (per 100 ...   numeric
# 1      WHS2_131  Age-standardized NCD mortality rate  (per 100 ...   numeric
#
#   ParentLocationCode   ParentLocation Location type SpatialDimValueCode  \
# 0                AFR           Africa       Country                 LSO
# 1                WPR  Western Pacific       Country                 FSM
#
#                            Location Period type  Period  ...  FactValueUoM  \
# 0                           Lesotho        Year    2019  ...           NaN
# 1  Micronesia (Federated States of)        Year    2019  ...           NaN
#
#   FactValueNumericLowPrefix FactValueNumericLow FactValueNumericHighPrefix  \
# 0                       NaN               588.3                        NaN
# 1                       NaN               594.8                        NaN
#
#    FactValueNumericHigh                Value  FactValueTranslationID  \
# 0                1958.0  1137 [588.3 – 1958]                     NaN
# 1                1938.0  1171 [594.8 – 1938]                     NaN
#
#    FactComments  Language              DateModified
# 0           NaN        EN  2021-02-09T05:00:00.000Z
# 1           NaN        EN  2021-02-09T05:00:00.000Z
#
# [2 rows x 34 columns]

# %%
wb.series.info()

# %%
#Graph Expectativa de vida(WORLD)
GEVW=wb.data.DataFrame("SP.DYN.LE00.IN",wb.region.members('WLD'),range(1990,2023,1))

# %%
GW=GEVW.transpose()

# %%
GF=GW.rename(index={"YR1990":"1990","YR1991":"1991","YR1992":"1992","YR1993":"1993","YR1994":"1994","YR1995":"1995","YR1996":"1996","YR1997":"1997","YR1998":"1998","YR1999":"1999","YR2000":"2000","YR2001":"2001","YR2002":"2002","YR2003":"2003","YR2004":"2004","YR2005":"2005","YR2006":"2006","YR2007":"2007","YR2008":"2008","YR2009":"2009","YR2010":"2010","YR2011":"2011","YR2012":"2012","YR2013":"2013","YR2014":"2014","YR2015":"2015","YR2016":"2016","YR2017":"2017","YR2018":"2018","YR2019":"2019","YR2020":"2020","YR2021":"2021"})

# %%
GF.index=GF.index.map(int)

# %%
GF
# Out:
# economy     ABW     AFG     AGO     ALB  AND     ARE     ARG     ARM  ASM  \
# 1990     73.468  50.331  45.306  71.836  NaN  71.939  71.594  67.879  NaN
# 1991     73.509  50.999  45.271  71.803  NaN  72.208  71.813  67.870  NaN
# 1992     73.544  51.641  45.230  71.802  NaN  72.466  72.032  67.990  NaN
# 1993     73.573  52.256  45.201  71.860  NaN  72.715  72.246  68.218  NaN
# 1994     73.598  52.842  45.201  71.992  NaN  72.957  72.453  68.538  NaN
# 1995     73.622  53.398  45.246  72.205  NaN  73.194  72.651  68.938  NaN
# 1996     73.646  53.924  45.350  72.495  NaN  73.428  72.843  69.404  NaN
# 1997     73.671  54.424  45.519  72.838  NaN  73.657  73.029  69.912  NaN
# 1998     73.700  54.906  45.763  73.208  NaN  73.883  73.213  70.434  NaN
# 1999     73.738  55.376  46.093  73.587  NaN  74.106  73.396  70.944  NaN
# 2000     73.787  55.841  46.522  73.955  NaN  74.327  73.576  71.409  NaN
# 2001     73.853  56.308  47.059  74.288  NaN  74.544  73.755  71.800  NaN
# 2002     73.937  56.784  47.702  74.579  NaN  74.758  73.932  72.112  NaN
# 2003     74.038  57.271  48.440  74.828  NaN  74.968  74.107  72.348  NaN
# 2004     74.156  57.772  49.263  75.039  NaN  75.174  74.280  72.513  NaN
# 2005     74.287  58.290  50.165  75.228  NaN  75.376  74.451  72.626  NaN
# 2006     74.429  58.826  51.143  75.423  NaN  75.573  74.620  72.716  NaN
# 2007     74.576  59.375  52.177  75.646  NaN  75.767  74.787  72.815  NaN
# 2008     74.725  59.930  53.243  75.912  NaN  75.957  74.952  72.946  NaN
# 2009     74.872  60.484  54.311  76.221  NaN  76.145  75.116  73.118  NaN
# 2010     75.017  61.028  55.350  76.562  NaN  76.332  75.278  73.331  NaN
# 2011     75.158  61.553  56.330  76.914  NaN  76.521  75.439  73.572  NaN
# 2012     75.299  62.054  57.236  77.252  NaN  76.711  75.598  73.820  NaN
# 2013     75.441  62.525  58.054  77.554  NaN  76.903  75.756  74.056  NaN
# 2014     75.583  62.966  58.776  77.813  NaN  77.095  75.913  74.273  NaN
# 2015     75.725  63.377  59.398  78.025  NaN  77.285  76.068  74.467  NaN
# 2016     75.868  63.763  59.925  78.194  NaN  77.470  76.221  74.640  NaN
# 2017     76.010  64.130  60.379  78.333  NaN  77.647  76.372  74.797  NaN
# 2018     76.152  64.486  60.782  78.458  NaN  77.814  76.520  74.945  NaN
# 2019     76.293  64.833  61.147  78.573  NaN  77.972  76.667  75.087  NaN
# 2020     76.434  65.173  61.487  78.686  NaN  78.120  76.813  75.224  NaN
# 2021        NaN     NaN     NaN     NaN  NaN     NaN     NaN     NaN  NaN
#
# economy     ATG  ...  VGB        VIR     VNM     VUT     WSM        XKX  \
# 1990     71.520  ...  NaN  74.235854  70.551  64.721  66.281  67.748780
# 1991     71.765  ...  NaN  74.491951  70.842  65.047  66.470  67.948780
# 1992     72.006  ...  NaN  74.747049  71.124  65.349  66.655  68.100000
# 1993     72.247  ...  NaN  75.002659  71.399  65.633  66.842  68.248780
# 1994     72.489  ...  NaN  75.257293  71.666  65.903  67.037  68.400000
# 1995     72.732  ...  NaN  75.509927  71.923  66.162  67.249  68.551220
# 1996     72.977  ...  NaN  75.759024  72.168  66.414  67.491  68.700000
# 1997     73.222  ...  NaN  76.002537  72.399  66.660  67.764  68.851220
# 1998     73.465  ...  NaN  76.236976  72.617  66.899  68.067  68.951220
# 1999     73.705  ...  NaN  76.461854  72.824  67.134  68.399  66.951220
# 2000     73.940  ...  NaN  76.619512  73.025  67.363  68.748  67.951220
# 2001     74.171  ...  NaN  77.621951  73.228  67.583  69.103  67.997561
# 2002     74.395  ...  NaN  77.521951  73.438  67.793  69.451  67.943902
# 2003     74.613  ...  NaN  77.521951  73.654  67.990  69.781  68.195122
# 2004     74.821  ...  NaN  77.773171  73.875  68.176  70.089  68.495122
# 2005     75.019  ...  NaN  77.421951  74.092  68.350  70.374  68.695122
# 2006     75.204  ...  NaN  78.324390  74.295  68.515  70.642  68.946341
# 2007     75.376  ...  NaN  76.863415  74.474  68.672  70.901  69.197561
# 2008     75.535  ...  NaN  77.163415  74.625  68.824  71.158  69.448780
# 2009     75.683  ...  NaN  77.514634  74.745  68.974  71.412  69.648780
# 2010     75.823  ...  NaN  77.865854  74.837  69.123  71.663  69.900000
# 2011     75.956  ...  NaN  78.317073  74.904  69.272  71.906  70.200000
# 2012     76.087  ...  NaN  78.517073  74.958  69.421  72.136  70.497561
# 2013     76.218  ...  NaN  78.717073  75.006  69.570  72.351  70.797561
# 2014     76.349  ...  NaN  78.868293  75.056  69.719  72.549  71.097561
# 2015     76.483  ...  NaN  79.017073  75.110  69.869  72.730  71.346341
# 2016     76.617  ...  NaN  79.168293  75.172  70.021  72.895  71.846341
# 2017     76.752  ...  NaN  79.368293  75.241  70.172  73.046  72.295122
# 2018     76.885  ...  NaN  79.519512  75.317  70.323  73.187  72.695122
# 2019     77.016  ...  NaN  79.668293  75.400  70.474  73.321  73.092683
# 2020     77.146  ...  NaN  79.819512  75.493  70.623  73.450  71.087805
# 2021        NaN  ...  NaN        NaN     NaN     NaN     NaN        NaN
#
# economy     YEM     ZAF     ZMB     ZWE
# 1990     57.346  63.307  49.249  58.100
# 1991     57.730  63.384  48.125  56.749
# 1992     58.047  63.247  46.987  55.243
# 1993     58.318  62.894  45.919  53.653
# 1994     58.566  62.331  44.983  52.044
# 1995     58.817  61.561  44.242  50.480
# 1996     59.096  60.595  43.735  49.009
# 1997     59.415  59.489  43.461  47.661
# 1998     59.782  58.315  43.413  46.466
# 1999     60.204  57.144  43.594  45.461
# 2000     60.683  56.048  44.000  44.649
# 2001     61.216  55.089  44.615  44.010
# 2002     61.781  54.310  45.400  43.523
# 2003     62.358  53.749  46.322  43.195
# 2004     62.931  53.444  47.354  43.065
# 2005     63.481  53.447  48.496  43.241
# 2006     63.997  53.795  49.757  43.853
# 2007     64.470  54.452  51.134  44.947
# 2008     64.892  55.360  52.606  46.504
# 2009     65.255  56.460  54.130  48.449
# 2010     65.549  57.669  55.655  50.640
# 2011     65.768  58.895  57.126  52.896
# 2012     65.920  60.060  58.502  55.032
# 2013     66.016  61.099  59.746  56.897
# 2014     66.066  61.968  60.831  58.410
# 2015     66.085  62.649  61.737  59.534
# 2016     66.087  63.153  62.464  60.294
# 2017     66.086  63.538  63.043  60.812
# 2018     66.096  63.857  63.510  61.195
# 2019     66.125  64.131  63.886  61.490
# 2020     66.181  64.379  64.194  61.738
# 2021        NaN     NaN     NaN     NaN
#
# [32 rows x 217 columns]

# %%
import pandas as pd
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import wbgapi as wb

# %%
#Life Expectancy in World
def lifexpo():
    fige=go.Figure()
    fige.update_layout(
            title={
                "text":"LifeExpectancy",
                "x" : 0.5,
                "xanchor":"center"
            },
            xaxis_title =" ",
            yaxis_title = "Esperanza de años",
            xaxis_rangeslider_visible=False
        )
    
    fige.add_trace(
                    go.Scatter(
                        x=GW.index,
                        name="India",
                        y=GW["PER"],
                        line = dict(color='red')
                    )

    )
        
    return fige

# %%
lifexpo()

# %%
# Crear CSV para entrenamiento y modelo
Exp=wb.data.DataFrame(["SP.ADO.TFRT",
"SP.DYN.CBRT.IN",
"SH.XPD.CHEX.GD.ZS",
"SH.XPD.CHEX.PC.CD",
"SP.DYN.TFRT.IN",
"SP.DYN.LE00.IN",
"SP.DYN.IMRT.IN",
"SP.POP.GROW",
"SP.POP.TOTL",
"SH.STA.SUIC.P5",
"NY.GDP.MKTP.KD",
"NY.GDP.MKTP.KN"],"PER",range(2010,2020,1))

# %%
Exp
# Out:
#                          YR2010        YR2011        YR2012        YR2013  \
# series
# NY.GDP.MKTP.KD     1.503007e+11  1.598105e+11  1.696225e+11  1.795496e+11
# NY.GDP.MKTP.KN     3.820810e+11  4.062560e+11  4.311990e+11  4.564350e+11
# SH.STA.SUIC.P5     3.500000e+00  3.300000e+00  3.200000e+00  3.100000e+00
# SH.XPD.CHEX.GD.ZS  4.715487e+00  4.533416e+00  4.740239e+00  4.760352e+00
# SH.XPD.CHEX.PC.CD  2.419287e+02  2.648850e+02  3.098474e+02  3.231655e+02
# SP.ADO.TFRT        6.601120e+01  6.416460e+01  6.231800e+01  6.123080e+01
# SP.DYN.CBRT.IN     2.062100e+01  2.010900e+01  1.961700e+01  1.918500e+01
# SP.DYN.IMRT.IN     1.530000e+01  1.460000e+01  1.390000e+01  1.330000e+01
# SP.DYN.LE00.IN     7.441000e+01  7.469700e+01  7.498100e+01  7.525800e+01
# SP.DYN.TFRT.IN     2.546000e+00  2.493000e+00  2.441000e+00  2.394000e+00
# SP.POP.GROW        8.129260e-01  8.118964e-01  8.251585e-01  9.014653e-01
# SP.POP.TOTL        2.902768e+07  2.926431e+07  2.950679e+07  2.977399e+07
#
#                          YR2014        YR2015        YR2016        YR2017  \
# series
# NY.GDP.MKTP.KD     1.838268e+11  1.898053e+11  1.973089e+11  2.022788e+11
# NY.GDP.MKTP.KN     4.673080e+11  4.825060e+11  5.015810e+11  5.142150e+11
# SH.STA.SUIC.P5     2.900000e+00  2.700000e+00  2.600000e+00  2.700000e+00
# SH.XPD.CHEX.GD.ZS  4.978508e+00  4.979630e+00  4.972741e+00  4.917768e+00
# SH.XPD.CHEX.PC.CD  3.346873e+02  3.127217e+02  3.135172e+02  3.348233e+02
# SP.ADO.TFRT        6.014360e+01  5.905640e+01  5.796920e+01  5.688200e+01
# SP.DYN.CBRT.IN     1.882700e+01  1.854400e+01  1.832300e+01  1.813400e+01
# SP.DYN.IMRT.IN     1.270000e+01  1.220000e+01  1.170000e+01  1.120000e+01
# SP.DYN.LE00.IN     7.552900e+01  7.579200e+01  7.604400e+01  7.628600e+01
# SP.DYN.TFRT.IN     2.355000e+00  2.323000e+00  2.297000e+00  2.275000e+00
# SP.POP.GROW        1.057019e+00  1.256159e+00  1.483157e+00  1.661928e+00
# SP.POP.TOTL        3.009037e+07  3.047074e+07  3.092604e+07  3.144430e+07
#
#                          YR2018        YR2019
# series
# NY.GDP.MKTP.KD     2.103080e+11  2.150202e+11
# NY.GDP.MKTP.KN     5.346260e+11  5.466050e+11
# SH.STA.SUIC.P5     2.800000e+00  2.800000e+00
# SH.XPD.CHEX.GD.ZS  5.197577e+00  5.215069e+00
# SH.XPD.CHEX.PC.CD  3.658638e+02  3.701100e+02
# SP.ADO.TFRT        5.595180e+01  5.502160e+01
# SP.DYN.CBRT.IN     1.794900e+01  1.775600e+01
# SP.DYN.IMRT.IN     1.070000e+01  1.030000e+01
# SP.DYN.LE00.IN     7.651600e+01  7.673600e+01
# SP.DYN.TFRT.IN     2.254000e+00  2.233000e+00
# SP.POP.GROW        1.718268e+00  1.616157e+00
# SP.POP.TOTL        3.198926e+07  3.251046e+07

# %%
Exf=Exp.transpose()

Ex=Exf.rename(index={"YR1990":"1990","YR1991":"1991","YR1992":"1992","YR1993":"1993","YR1994":"1994","YR1995":"1995","YR1996":"1996","YR1997":"1997","YR1998":"1998","YR1999":"1999","YR2000":"2000","YR2001":"2001","YR2002":"2002","YR2003":"2003","YR2004":"2004","YR2005":"2005","YR2006":"2006","YR2007":"2007","YR2008":"2008","YR2009":"2009","YR2010":"2010","YR2011":"2011","YR2012":"2012","YR2013":"2013","YR2014":"2014","YR2015":"2015","YR2016":"2016","YR2017":"2017","YR2018":"2018","YR2019":"2019","YR2020":"2020","YR2021":"2021"})
Ex.index=Ex.index.map(int)

# %%
Ex
# Out:
# series  NY.GDP.MKTP.KD  NY.GDP.MKTP.KN  SH.STA.SUIC.P5  SH.XPD.CHEX.GD.ZS  \
# 2010      1.503007e+11    3.820810e+11             3.5           4.715487
# 2011      1.598105e+11    4.062560e+11             3.3           4.533416
# 2012      1.696225e+11    4.311990e+11             3.2           4.740239
# 2013      1.795496e+11    4.564350e+11             3.1           4.760352
# 2014      1.838268e+11    4.673080e+11             2.9           4.978508
# 2015      1.898053e+11    4.825060e+11             2.7           4.979630
# 2016      1.973089e+11    5.015810e+11             2.6           4.972741
# 2017      2.022788e+11    5.142150e+11             2.7           4.917768
# 2018      2.103080e+11    5.346260e+11             2.8           5.197577
# 2019      2.150202e+11    5.466050e+11             2.8           5.215069
#
# series  SH.XPD.CHEX.PC.CD  SP.ADO.TFRT  SP.DYN.CBRT.IN  SP.DYN.IMRT.IN  \
# 2010           241.928696      66.0112          20.621            15.3
# 2011           264.885040      64.1646          20.109            14.6
# 2012           309.847382      62.3180          19.617            13.9
# 2013           323.165527      61.2308          19.185            13.3
# 2014           334.687317      60.1436          18.827            12.7
# 2015           312.721710      59.0564          18.544            12.2
# 2016           313.517181      57.9692          18.323            11.7
# 2017           334.823334      56.8820          18.134            11.2
# 2018           365.863831      55.9518          17.949            10.7
# 2019           370.109955      55.0216          17.756            10.3
#
# series  SP.DYN.LE00.IN  SP.DYN.TFRT.IN  SP.POP.GROW  SP.POP.TOTL
# 2010            74.410           2.546     0.812926   29027680.0
# 2011            74.697           2.493     0.811896   29264314.0
# 2012            74.981           2.441     0.825158   29506790.0
# 2013            75.258           2.394     0.901465   29773986.0
# 2014            75.529           2.355     1.057019   30090372.0
# 2015            75.792           2.323     1.256159   30470739.0
# 2016            76.044           2.297     1.483157   30926036.0
# 2017            76.286           2.275     1.661928   31444299.0
# 2018            76.516           2.254     1.718268   31989265.0
# 2019            76.736           2.233     1.616157   32510462.0

# %%
Ex.to_csv("Peru2.csv",index=False)

# %%
def interpolacion(d, x):
    output = d[0][1] + (x - d[0][0]) * ((d[1][1] - d[0][1])/(d[1][0] - d[0][0]))
  
    return output
#  Code
x=1999
y=2021
year_x=x
data=[[2000,73.65684509],[2019,20.57073212]]
for i in range(x,y):
    year_x=i
  

  
# Encontrando el valor de   la interpolacion
    print("En  {} el valor es".format(year_x),
             interpolacion(data, year_x))
# Out:
# En  1999 el valor es 76.45085103578948
# En  2000 el valor es 73.65684509
# En  2001 el valor es 70.86283914421053
# En  2002 el valor es 68.06883319842106
# En  2003 el valor es 65.27482725263158
# En  2004 el valor es 62.48082130684211
# En  2005 el valor es 59.68681536105264
# En  2006 el valor es 56.89280941526316
# En  2007 el valor es 54.09880346947369
# En  2008 el valor es 51.304797523684215
# En  2009 el valor es 48.51079157789474
# En  2010 el valor es 45.71678563210527
# En  2011 el valor es 42.92277968631579
# En  2012 el valor es 40.12877374052632
# En  2013 el valor es 37.33476779473685
# En  2014 el valor es 34.54076184894737
# En  2015 el valor es 31.746755903157897
# En  2016 el valor es 28.952749957368425
# En  2017 el valor es 26.158744011578953
# En  2018 el valor es 23.36473806578948
# En  2019 el valor es 20.570732120000002
# En  2020 el valor es 17.77672617421053

# %%
  
def interpolation(d, x):
    output = d[0][1] + (x - d[0][0]) * ((d[1][1] - d[0][1])/(d[1][0] - d[0][0]))
  
    return output
  
# Driver Code
data=[[2002, 200],[2015, 500]]
  
year_x=2003
  
# Finding the interpolation
print("Population on year {} is".format(year_x),
             interpolation(data, year_x))
# Out:
# Population on year 2003 is 223.07692307692307

# %%
import matplotlib.pyplot as plt 
import numpy as np 
from scipy.interpolate import InterpolatedUnivariateSpline

# %%
# given values
xi = np.array([0.2, 0.5, 0.7, 0.9])
yi = np.array([0.3, -0.1, 0.2, 0.1])
# positions to inter/extrapolate
x = np.linspace(0,1,50)
# spline order: 1 linear, 2 quadratic, 3 cubic ... 
order = 1 
# do inter/extrapolation
s = InterpolatedUnivariateSpline(xi, yi, k=order)
y = s(x)

# example showing the interpolation for linear, quadratic and cubic interpolation
plt.figure()
plt.plot(xi,yi)
for order in range(1,4):
    s = InterpolatedUnivariateSpline(xi, yi, k=order)
    y = s(x)
    plt.plot(x,y)
plt.show()

# %%
s

# %%
from scipy.interpolate import interp1d 
from scipy import arange, array, exp

# %%
def extrap1d(interpolator): 
    xs = interpolator.x 
    ys = interpolator.y 
    def pointwise(x): 
        if x < xs[0]: 
            return ys[0]+(x-xs[0])*(ys[1]-ys[0])/(xs[1]-xs[0]) 
        elif x > xs[-1]:
            return ys[-1]+(x-xs[-1])*(ys[-1]-ys[-2])/(xs[-1]-xs[-2]) 
        else:
            return interpolator(x) 
    def ufunclike(xs):
        return array(map(pointwise, array(xs))) 
    return ufunclike

# %%
# Implementation of Linear Interpolation using Python3 code
# Importing library
from scipy.interpolate import interp1d
  
X = [1,2,3,4,5] # random x values 
Y = [11,2.2,3.5,-88,1] # random y values
  
# test value
interpolate_x = 2.5
  
# Finding the interpolation
y_interp = interp1d(X, Y)
print("Value of Y at x = {} is".format(interpolate_x),
      y_interp(interpolate_x))
# Out:
# Value of Y at x = 2.5 is 2.85

# %%
import pandas as pd

# %%
afkc=pd.read_csv("SAS2.csv")
afkc.tail()
# Out:
#      date countryiso3code  SH.XPD.CHEX.PC.CD  SH.XPD.CHEX.GD.ZS  SP.ADO.TFRT  \
# 155  2021             BGD         155.956116          11.265896   222.302353
# 156  2021             IND         146.663544          10.714028   170.428345
# 157  2021             LKA          93.959915           6.467360   107.941360
# 158  2021             NPL         -26.519453          -0.063788    22.841064
# 159  2021             PAK         -31.823057          -1.075171   -11.427399
#
#          SP.POP.GROW  SP.POP.TOTL  SP.DYN.CBRT.IN  SP.DYN.TFRT.IN  \
# 155  975322375425237    166303494       86.313194       11.899710
# 156  966660959674886   1393409033       74.719490       10.300407
# 157  107544995696428     22156000       44.943916        5.975401
# 158  182999900040487     29674920       -0.013391       -0.513999
# 159  193131882333006    225199929       -2.987566       -0.689862
#
#      SP.DYN.LE00.IN  SP.DYN.IMRT.IN  SH.STA.SUIC.P5  NCD_BMI_25A  \
# 155      201.388504      205.030899       49.208393   187.230942
# 156      178.067032      177.589935       48.488457   164.272980
# 157      117.335480       88.264114       27.552923    96.627899
# 158        1.276012      -12.322447      -10.111073   -23.564280
# 159       -6.174360      -13.495605      -11.784658   -26.018373
#
#       NY.GDP.MKTP.KN  NCD_HYP_PREVALENCE_A
# 155   28339444000000            378.390869
# 156  147716805405700            332.299072
# 157  988139658938549            200.954498
# 158  238131250601576            -28.193935
# 159   38902034000000            -41.893894

# %%
afkc
# Out:
#      date countryiso3code  SH.XPD.CHEX.PC.CD  SH.XPD.CHEX.GD.ZS  SP.ADO.TFRT  \
# 0    1990             BGD          23.363583           4.101981   153.961400
# 1    1990             IND          28.888153           4.108372    98.789200
# 2    1990             LKA          42.147995           2.949029    30.984200
# 3    1990             NPL          18.689777           4.136695   131.649600
# 4    1990             PAK          23.479807           3.565211    86.087800
# ..    ...             ...                ...                ...          ...
# 155  2021             BGD         155.956116          11.265896   222.302353
# 156  2021             IND         146.663544          10.714028   170.428345
# 157  2021             LKA          93.959915           6.467360   107.941360
# 158  2021             NPL         -26.519453          -0.063788    22.841064
# 159  2021             PAK         -31.823057          -1.075171   -11.427399
#
#          SP.POP.GROW  SP.POP.TOTL  SP.DYN.CBRT.IN  SP.DYN.TFRT.IN  \
# 0    242960098122108    103171957       35.099000        4.495000
# 1    207608920383876    873277799       31.517000        4.045000
# 2    127216914397561     17325769       20.624000        2.483000
# 3    246573575610948     18905480       38.458000        5.172000
# 4     29555623179075    107647918       41.222000        6.164000
# ..               ...          ...             ...             ...
# 155  975322375425237    166303494       86.313194       11.899710
# 156  966660959674886   1393409033       74.719490       10.300407
# 157  107544995696428     22156000       44.943916        5.975401
# 158  182999900040487     29674920       -0.013391       -0.513999
# 159  193131882333006    225199929       -2.987566       -0.689862
#
#      SP.DYN.LE00.IN  SP.DYN.IMRT.IN  SH.STA.SUIC.P5  NCD_BMI_25A  \
# 0         58.210000      101.100000        9.177618    25.100000
# 1         57.865000       88.600000       12.891262    26.700000
# 2         69.509000       19.400000       12.568281    32.700000
# 3         54.404000       96.500000        8.096279    26.600000
# 4         60.100000      106.900000        8.890778    40.800000
# ..              ...             ...             ...          ...
# 155      201.388504      205.030899       49.208393   187.230942
# 156      178.067032      177.589935       48.488457   164.272980
# 157      117.335480       88.264114       27.552923    96.627899
# 158        1.276012      -12.322447      -10.111073   -23.564280
# 159       -6.174360      -13.495605      -11.784658   -26.018373
#
#       NY.GDP.MKTP.KN  NCD_HYP_PREVALENCE_A
# 0    524867336491619             87.600000
# 1     25145486613000             86.300000
# 2      2330467880500             95.700000
# 3    630972867623059            102.400000
# 4    114087026804122            112.200000
# ..               ...                   ...
# 155   28339444000000            378.390869
# 156  147716805405700            332.299072
# 157  988139658938549            200.954498
# 158  238131250601576            -28.193935
# 159   38902034000000            -41.893894
#
# [160 rows x 15 columns]

# %%
from client import SAS4

# %%
SAS4
# Out:
#      date countryiso3code  SH.XPD.CHEX.PC.CD  SH.XPD.CHEX.GD.ZS  SP.ADO.TFRT  \
# 0    1990             AFG          28.907116           8.289868     162.8354
# 1    1990             BGD          24.458607           5.461570     153.9614
# 2    1990             IND          30.245655           5.214283      98.7892
# 3    1990             LKA          43.179916           3.276813      30.9842
# 4    1990             NPL          21.723875           5.712186     131.6496
# ..    ...             ...                ...                ...          ...
# 181  2020             BGD          31.828695           2.948783      81.0144
# 182  2020             IND          49.158169           3.891968       9.8584
# 183  2020             LKA          56.351654           3.271339      20.2192
# 184  2020             NPL          27.538715           2.850724      62.9550
# 185  2020             PAK          32.229439           3.333475      37.0278
#
#          SP.POP.GROW  SP.POP.TOTL  SP.DYN.CBRT.IN  SP.DYN.TFRT.IN  \
# 0    447695437953718     12412311          48.880           7.466
# 1    242960098122108    103171957          35.099           4.495
# 2    207608920383876    873277799          31.517           4.045
# 3    127216914397561     17325769          20.624           2.483
# 4    246573575610948     18905480          38.458           5.172
# ..               ...          ...             ...             ...
# 181  100277418143487    164689383          17.549           1.987
# 182  989413800188014   1380004385          17.437           2.184
# 183  530626559530355     21919000          15.253           2.174
# 184   18290862928371     29136808          19.256           1.845
# 185  197831956650447    220892331          27.379           3.394
#
#      SP.DYN.LE00.IN  SP.DYN.IMRT.IN  SH.STA.SUIC.P5  NCD_BMI_25A  \
# 0            50.331           120.8        5.750034    30.800000
# 1            58.210           101.1        6.236084    25.100000
# 2            57.865            88.6       10.706396    26.700000
# 3            69.509            19.4       12.312767    32.700000
# 4            54.404            96.5        5.891539    26.600000
# ..              ...             ...             ...          ...
# 181          72.868            24.3        7.565247    32.746326
# 182          69.887            27.0       15.234110    40.484196
# 183          77.144             5.9       14.376536    40.732231
# 184          71.067            23.6        7.058941    29.977396
# 185          67.428            54.2        7.847215    42.095341
#
#        NY.GDP.MKTP.KN  NCD_HYP_PREVALENCE_A
# 0                 NaN            106.400000
# 1    5248673364916,19             87.600000
# 2      25145486613000             86.300000
# 3       2330467880500             95.700000
# 4    630972867623,059            102.400000
# ..                ...                   ...
# 181    26500650000000             75.776886
# 182   135584734020400             89.088112
# 183  9532908510880,47             88.729218
# 184  2284299666526,91             75.801193
# 185    36689734000000             91.683517
#
# [186 rows x 15 columns]

# %%
AFR4[AFR4["countryiso3code"]=="ETH"]
# Out:
# Empty DataFrame
# Columns: [date, countryiso3code, SH.XPD.CHEX.PC.CD, SH.XPD.CHEX.GD.ZS, SP.ADO.TFRT, SP.POP.GROW, SP.POP.TOTL, SP.DYN.CBRT.IN, SP.DYN.TFRT.IN, SP.DYN.LE00.IN, SP.DYN.IMRT.IN, SH.STA.SUIC.P5, NCD_BMI_25A, NY.GDP.MKTP.KN, NCD_HYP_PREVALENCE_A]
# Index: []

# %%
AfrgZ()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\USER\Documents\GitHub\Streamlit_test\test.ipynb Celda 84 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/Streamlit_test/test.ipynb#Y146sZmlsZQ%3D%3D?line=0'>1</a> AfrgZ()
#
# c:\Users\USER\Documents\GitHub\Streamlit_test\test.ipynb Celda 84 in AfrgZ()
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/Streamlit_test/test.ipynb#Y146sZmlsZQ%3D%3D?line=0'>1</a> def AfrgZ():
# ----> <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/Streamlit_test/test.ipynb#Y146sZmlsZQ%3D%3D?line=1'>2</a>     fig=go.Figure()
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/Streamlit_test/test.ipynb#Y146sZmlsZQ%3D%3D?line=2'>3</a>     fig = make_subplots(rows=2, cols=1, shared_xaxes=True,
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/Streamlit_test/test.ipynb#Y146sZmlsZQ%3D%3D?line=3'>4</a>                vertical_spacing=0.13, subplot_titles=('', ''),
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/Streamlit_test/test.ipynb#Y146sZmlsZQ%3D%3D?line=4'>5</a>                row_width=[0.2, 0.7])
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/Streamlit_test/test.ipynb#Y146sZmlsZQ%3D%3D?line=5'>6</a>     fig.update_layout(
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/Streamlit_test/test.ipynb#Y146sZmlsZQ%3D%3D?line=6'>7</a>             title={
#       <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/Streamlit_test/test.ipynb#Y146sZmlsZQ%3D%3D?line=7'>8</a>                 "text":"Adolescent fertility rate",
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/Streamlit_test/test.ipynb#Y146sZmlsZQ%3D%3D?line=13'>14</a>             xaxis_rangeslider_visible=False
#      <a href='vscode-notebook-cell:/c%3A/Users/USER/Documents/GitHub/Streamlit_test/test.ipynb#Y146sZmlsZQ%3D%3D?line=14'>15</a>         )
#
# NameError: name 'go' is not defined

# %%
def AfrgZ():
    fig=go.Figure()
    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, 
               vertical_spacing=0.13, subplot_titles=('', ''), 
               row_width=[0.2, 0.7])
    fig.update_layout(
            title={
                "text":"Adolescent fertility rate",
                "x" : 0.5,
                "xanchor":"center"
            },
            xaxis_title ="Volumen",
            yaxis_title = "quantity",
            xaxis_rangeslider_visible=False
        )
    fig.add_trace(
                    go.Scatter(
                        x=AFR4[AFR4["countryiso3code"]=="NER"].date,
                        name="Nigeria",
                        y=AFR4[AFR4["countryiso3code"]=="NER"].iloc[:,4],
                        line = dict(color="gold")
                    )
            )
    fig.add_trace(
                    go.Scatter(
                        x=AFR4[AFR4["countryiso3code"]=="ETH"].date,
                        name="Ethiopia",
                        y=AFR4[AFR4["countryiso3code"]=="ETH"].iloc[:,4],
                        line = dict(color="skyblue")
                    )
            )
    fig.add_trace(
                    go.Scatter(
                        x=AFR4[AFR4["countryiso3code"]=="EGY"].date,
                        name="Egipto",
                        y=AFR4[AFR4["countryiso3code"]=="EGY"].iloc[:,4],
                        line = dict(color="red")
                    )
            )
    
    fig.add_trace(
                    go.Scatter(
                        x=AFR4[AFR4["countryiso3code"]=="COD"].date,
                        name="Congo",
                        y=AFR4[AFR4["countryiso3code"]=="COD"].iloc[:,4],
                        line = dict(color="brown")
                    )
            )
    fig.add_trace(
                    go.Scatter(
                        x=AFR4[AFR4["countryiso3code"]=="TZA"].date,
                        name="Tanzania",
                        y=AFR4[AFR4["countryiso3code"]=="TZA"].iloc[:,4],
                        line = dict(color="black")
                    )
            )
    fig.add_trace(
                    go.Scatter(
                        x=AFR4[AFR4["countryiso3code"]=="ZAF"].date,
                        name="South Africa",
                        y=AFR4[AFR4["countryiso3code"]=="ZAF"].iloc[:,4],
                        line = dict(color="green")
                    )
    
            )
    fig.add_trace(
                    go.Scatter(
                        x=AFR4["date"],
                        name="CLA",
                        y=AFR4['SP.ADO.TFRT'],
                        line = dict(color="black")
                    )
            )
    fig.add_trace(
                        go.Bar(
                        x=AFR4['date'],
                        y=AFR4['SP.ADO.TFRT'],
                        name="Volumen",
                        showlegend=False),
                        row=2, col=1
    
)
                    
    return fig

# %%
def ClagZ():
    fig=go.Figure()

    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, 
               vertical_spacing=0.13, subplot_titles=('', ''), 
               row_width=[0.2, 0.7])
    fig.update_layout(
            title={
                "text":"Adolescent fertility rate",
                "x" : 0.5,
                "xanchor":"center"
            },
            xaxis_title ="Volumen",
            yaxis_title = "quantity",
            xaxis_rangeslider_visible=False
        )
    fig.add_trace(
                    go.Scatter(
                        x=CLA4[CLA4["countryiso3code"]=="BRA"].date,
                        name="Brazil",
                        y=CLA4[CLA4["countryiso3code"]=="BRA"].iloc[:,4],
                        line = dict(color="gold")
                    )
            )
    fig.add_trace(
                    go.Scatter(
                        x=CLA4[CLA4["countryiso3code"]=="ARG"].date,
                        name="Argentina",
                        y=CLA4[CLA4["countryiso3code"]=="ARG"].iloc[:,4],
                        line = dict(color="skyblue")
                    )
            )
    fig.add_trace(
                    go.Scatter(
                        x=CLA4[CLA4["countryiso3code"]=="PER"].date,
                        name="Perú",
                        y=CLA4[CLA4["countryiso3code"]=="PER"].iloc[:,4],
                        line = dict(color="red")
                    )
            )
    
    fig.add_trace(
                    go.Scatter(
                        x=CLA4[CLA4["countryiso3code"]=="MEX"].date,
                        name="Mexico",
                        y=CLA4[CLA4["countryiso3code"]=="MEX"].iloc[:,4],
                        line = dict(color="brown")
                    )
            )
    fig.add_trace(
                    go.Scatter(
                        x=CLA4[CLA4["countryiso3code"]=="COL"].date,
                        name="Colombia",
                        y=CLA4[CLA4["countryiso3code"]=="COL"].iloc[:,4],
                        line = dict(color="black")
                    )
            )
    fig.add_trace(
                    go.Scatter(
                        x=CLA4[CLA4["countryiso3code"]=="CHL"].date,
                        name="Chile",
                        y=CLA4[CLA4["countryiso3code"]=="CHL"].iloc[:,4],
                        line = dict(color="green")
                    )
            )
    fig.add_trace(
                    go.Scattergeo(
                        x=CLA4["date"],
                        name="CLA",
                        y=CLA4['SP.ADO.TFRT'],
                        line = dict(color="black")
                    )
            )
    
            
    fig.add_trace(
                        go.Bar(
                        x=CLA4['date'],
                        y=CLA4['SP.ADO.TFRT'],
                        name="Volumen",
                        showlegend=False),
                        row=2, col=1
    
) 
                    
    return fig

# %%
CLAZ.iloc[:,4]

# %%
CLAZ[CLAZ["countryiso3code"]=="BRA"].iloc[:,4]

# %%
CALSDASD=CLAZ["countryiso3code"]=="BRA"
CLAZ[CALSDASD]

# %%
ClagZ()

# %%
dropclaz=CLAZ.date==2021

# %%
import pandas as pd

# %%
asdasdasd=pd.read_csv("CLA4.csv")
asdasdasd
# Out:
#      date countryiso3code  SH.XPD.CHEX.PC.CD  SH.XPD.CHEX.GD.ZS  SP.ADO.TFRT  \
# 0    1990             ARG         734.103882           9.246048      73.4930
# 1    1990             BRA         512.131592           9.014139      82.9406
# 2    1990             CHL         537.907043           7.159102      66.1100
# 3    1990             COL         416.916565           7.125776      96.2052
# 4    1990             MEX         562.431580           7.704775      86.2706
# ..    ...             ...                ...                ...          ...
# 181  2020             BRA         337.427185           5.262487      55.4354
# 182  2020             CHL         296.598633           3.364405      38.3112
# 183  2020             COL         184.572418           3.501940      63.1440
# 184  2020             MEX         267.994781           3.243899      57.6326
# 185  2020             PER         182.194916           3.131345      54.0914
#
#       SP.POP.GROW  SP.POP.TOTL  SP.DYN.CBRT.IN  SP.DYN.TFRT.IN  \
# 0    1.452965e+14     32618648          22.226           2.997
# 1    1.811519e+14    149003225          24.844           2.902
# 2    1.639470e+14     13274617          22.286           2.579
# 3    1.967944e+16     33102569          27.136           3.082
# 4    1.893130e+14     83943135          28.802           3.470
# ..            ...          ...             ...             ...
# 181  7.128728e+14    212559409          13.463           1.706
# 182  8.625300e+14     19116209          11.990           1.611
# 183  1.073767e+14     50882884          14.415           1.771
# 184  1.058240e+14    128932753          17.005           2.079
# 185  1.409210e+14     32971846          17.544           2.212
#
#      SP.DYN.LE00.IN  SP.DYN.IMRT.IN  SH.STA.SUIC.P5  NCD_BMI_25A  \
# 0            71.594            25.3        8.322419   146.100000
# 1            66.343            52.6        3.850654   115.300000
# 2            73.509            16.1        7.254542   146.300000
# 3            69.750            29.2        4.131992   128.400000
# 4            70.866            36.3        4.764493   146.600000
# ..              ...             ...             ...          ...
# 181          76.084            13.1        2.484264    99.498642
# 182          80.329             5.8        4.698891    93.437683
# 183          77.460            11.4        2.031748    92.810165
# 184          75.131            11.8        1.692562    93.910271
# 185          76.947            10.0        2.106421    88.406708
#
#       NY.GDP.MKTP.KN  NCD_HYP_PREVALENCE_A
# 0       322461423550            112.400000
# 1    209267626216386            117.800000
# 2    522996042828507            110.000000
# 3    330352934040000             87.200000
# 4      9241452512000             88.400000
# ..               ...                   ...
# 181  399069254847478             86.796051
# 182  179482434842800             61.320045
# 183  819114000000000             56.119102
# 184   16975827704000             55.551174
# 185     486737000000             41.274193
#
# [186 rows x 15 columns]

# %%
SAS3=asdasdasd.drop(asdasdasd.tail(6).index)

# %%
SAS3
# Out:
#      date countryiso3code  SH.XPD.CHEX.PC.CD  SH.XPD.CHEX.GD.ZS  SP.ADO.TFRT  \
# 0    1990             AFG          28.907116           8.289868     162.8354
# 1    1990             BGD          24.458607           5.461570     153.9614
# 2    1990             IND          30.245655           5.214283      98.7892
# 3    1990             LKA          43.179916           3.276813      30.9842
# 4    1990             NPL          21.723875           5.712186     131.6496
# ..    ...             ...                ...                ...          ...
# 181  2020             BGD          31.828695           2.948783      81.0144
# 182  2020             IND          49.158169           3.891968       9.8584
# 183  2020             LKA          56.351654           3.271339      20.2192
# 184  2020             NPL          27.538715           2.850724      62.9550
# 185  2020             PAK          32.229439           3.333475      37.0278
#
#          SP.POP.GROW  SP.POP.TOTL  SP.DYN.CBRT.IN  SP.DYN.TFRT.IN  \
# 0    447695437953718     12412311          48.880           7.466
# 1    242960098122108    103171957          35.099           4.495
# 2    207608920383876    873277799          31.517           4.045
# 3    127216914397561     17325769          20.624           2.483
# 4    246573575610948     18905480          38.458           5.172
# ..               ...          ...             ...             ...
# 181  100277418143487    164689383          17.549           1.987
# 182  989413800188014   1380004385          17.437           2.184
# 183  530626559530355     21919000          15.253           2.174
# 184   18290862928371     29136808          19.256           1.845
# 185  197831956650447    220892331          27.379           3.394
#
#      SP.DYN.LE00.IN  SP.DYN.IMRT.IN  SH.STA.SUIC.P5  NCD_BMI_25A  \
# 0            50.331           120.8        5.750034    30.800000
# 1            58.210           101.1        6.236084    25.100000
# 2            57.865            88.6       10.706396    26.700000
# 3            69.509            19.4       12.312767    32.700000
# 4            54.404            96.5        5.891539    26.600000
# ..              ...             ...             ...          ...
# 181          72.868            24.3        7.565247    32.746326
# 182          69.887            27.0       15.234110    40.484196
# 183          77.144             5.9       14.376536    40.732231
# 184          71.067            23.6        7.058941    29.977396
# 185          67.428            54.2        7.847215    42.095341
#
#        NY.GDP.MKTP.KN  NCD_HYP_PREVALENCE_A
# 0                 NaN            106.400000
# 1    5248673364916,19             87.600000
# 2      25145486613000             86.300000
# 3       2330467880500             95.700000
# 4    630972867623,059            102.400000
# ..                ...                   ...
# 181    26500650000000             75.776886
# 182   135584734020400             89.088112
# 183  9532908510880,47             88.729218
# 184  2284299666526,91             75.801193
# 185    36689734000000             91.683517
#
# [186 rows x 15 columns]

# %%
SAS3.to_csv("SAS4.csv",index=False)

# %%
dsad=pd.read_csv("SAS4.csv")
dsad
# Out:
#      date countryiso3code  SH.XPD.CHEX.PC.CD  SH.XPD.CHEX.GD.ZS  SP.ADO.TFRT  \
# 0    1990             AFG          28.907116           8.289868     162.8354
# 1    1990             BGD          24.458607           5.461570     153.9614
# 2    1990             IND          30.245655           5.214283      98.7892
# 3    1990             LKA          43.179916           3.276813      30.9842
# 4    1990             NPL          21.723875           5.712186     131.6496
# ..    ...             ...                ...                ...          ...
# 181  2020             BGD          31.828695           2.948783      81.0144
# 182  2020             IND          49.158169           3.891968       9.8584
# 183  2020             LKA          56.351654           3.271339      20.2192
# 184  2020             NPL          27.538715           2.850724      62.9550
# 185  2020             PAK          32.229439           3.333475      37.0278
#
#          SP.POP.GROW  SP.POP.TOTL  SP.DYN.CBRT.IN  SP.DYN.TFRT.IN  \
# 0    447695437953718     12412311          48.880           7.466
# 1    242960098122108    103171957          35.099           4.495
# 2    207608920383876    873277799          31.517           4.045
# 3    127216914397561     17325769          20.624           2.483
# 4    246573575610948     18905480          38.458           5.172
# ..               ...          ...             ...             ...
# 181  100277418143487    164689383          17.549           1.987
# 182  989413800188014   1380004385          17.437           2.184
# 183  530626559530355     21919000          15.253           2.174
# 184   18290862928371     29136808          19.256           1.845
# 185  197831956650447    220892331          27.379           3.394
#
#      SP.DYN.LE00.IN  SP.DYN.IMRT.IN  SH.STA.SUIC.P5  NCD_BMI_25A  \
# 0            50.331           120.8        5.750034    30.800000
# 1            58.210           101.1        6.236084    25.100000
# 2            57.865            88.6       10.706396    26.700000
# 3            69.509            19.4       12.312767    32.700000
# 4            54.404            96.5        5.891539    26.600000
# ..              ...             ...             ...          ...
# 181          72.868            24.3        7.565247    32.746326
# 182          69.887            27.0       15.234110    40.484196
# 183          77.144             5.9       14.376536    40.732231
# 184          71.067            23.6        7.058941    29.977396
# 185          67.428            54.2        7.847215    42.095341
#
#        NY.GDP.MKTP.KN  NCD_HYP_PREVALENCE_A
# 0                 NaN            106.400000
# 1    5248673364916,19             87.600000
# 2      25145486613000             86.300000
# 3       2330467880500             95.700000
# 4    630972867623,059            102.400000
# ..                ...                   ...
# 181    26500650000000             75.776886
# 182   135584734020400             89.088112
# 183  9532908510880,47             88.729218
# 184  2284299666526,91             75.801193
# 185    36689734000000             91.683517
#
# [186 rows x 15 columns]

# %%
dropclaz
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 187     True
# 188     True
# 189     True
# 190     True
# 191     True
# Name: date, Length: 192, dtype: bool
